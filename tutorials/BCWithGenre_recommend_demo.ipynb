# %% [markdown]
# ## 基于电影风格偏好的推荐系统算法

# %% [markdown]
# 该算法的核心思想：首先，找出用户最喜爱的电影风格；然后，找出各类风格中评分最高的电影集合；最后，将用户喜爱风格中评分最高的电影，按比例的数量推荐给用户。

# %%
# coding=utf-8
import sys
import pandas as pd
import operator
import time

# %% [markdown]
# ### 读取数据

# %%
movies = pd.read_csv('/home/zwj/Desktop/recommend/movielens/moive_database/v1/v1_movie_info.csv',\
                        usecols=[0, 1, 6], header=0, names=['movieId', 'title', 'genres'])

df_train = pd.read_csv('/home/zwj/Desktop/recommend/movielens/moive_database/v1/v1_train.csv')  
# userId, movieId, rating, timestamp

# %% [markdown]
# ### 设置参数

# %%
# 推荐电影数
reco_num = 10
# 电影信息表文件路径
movie_info_path = '/home/zwj/Desktop/recommend/movielens/moive_database/v1/v1_movie_info.csv'

# %% [markdown]
# ### 功能函数

# %% [markdown]
# 获取全局热门电影

# %%
def getHotItem(df_train, N=5):
    """
    param:
        df_train: 训练数据集 type:dataframe
        N: 推荐的电影数
    return: 
        hot_rank: 该用户的推荐热门电影列表 type:dict, key:user, value:dict, key:item, value:sim
    """

    item_count = df_train.groupby('movieId')['rating'].count().sort_values(ascending=False)

    hot_rank = {}

    r = 0
    for item_id in item_count[0:N].index:
        hot_rank[item_id] = 1 - 0.01 * r
        r += 1
    return hot_rank

hot_rank = getHotItem(df_train, reco_num)

hot_rank
# Out:
# {1: 0.94,
#  50: 1.0,
#  56: 0.91,
#  100: 0.97,
#  174: 0.92,
#  181: 0.99,
#  258: 0.98,
#  288: 0.95,
#  294: 0.96,
#  300: 0.9299999999999999}

# %% [markdown]
# 生成用户-电影排列表

# %%
def userItemDict(data):
    """
    param:
        data: lsit [user, item, rating]
    return:
        user_item: 用户-电影排列表 type:dict, key:user, value:dict, key:item, value:rate
    """
    user_item = {}
    for user, item, rate, timestamp in data:
        if user not in user_item:
            user_item[user] = {}
        user_item[user].update({item: rate})
    return user_item

# 生成user-tiem排列表
user_item = userItemDict(df_train.values)

user_item[105]
# Out:
# {264.0: 2.0,
#  270.0: 5.0,
#  271.0: 2.0,
#  288.0: 4.0,
#  302.0: 5.0,
#  313.0: 5.0,
#  324.0: 4.0,
#  327.0: 4.0,
#  340.0: 3.0,
#  343.0: 2.0,
#  347.0: 3.0,
#  690.0: 3.0,
#  751.0: 2.0,
#  880.0: 3.0}

# %% [markdown]
# 获得item的全局平均得分

# %%
def getItemAveScore(data):
    """
    param:
        data: type ndarray [[user, item, rating]]
    return:
        ave_score: item的全局平均得分字典 type dict, key:item, value: ratio
    """

    # 中间字典 key: item, value: list [rate_sum, rate_count]
    record_tmp = {}
    ave_score = {}

    for user, item, rate in data:
        if item not in record_tmp:
            record_tmp[item] = [0, 0]
        record_tmp[item][0] += rate
        record_tmp[item][1] += 1
    for item in record_tmp:
        # 保存item的平均得分
        ave_score[item] = round(record_tmp[item][0] / record_tmp[item][1], 3)
    return ave_score

ave_score = getItemAveScore(df_train[['userId', 'movieId', 'rating']].values)

# %% [markdown]
# 规范化电影风格格式

# %%
def getGenre(genre_str):
    """
    param:
        genre_str: 字符串 如"Drama|Mystery|Romance|"
    return:
        genre_list: 风格列表 ['Drama', 'Mystery', 'Romance']
    """
    genre_list = []
    empty = 0
    # 当genres字段为空时，跳过
    if genre_str == "" or genre_str == "unknown":
        empty = 1
        return genre_list, empty
    # 字符串处理，按"|"分割字符串,list最后一个元素为空，所以去掉
    genre_list = genre_str.strip().split("|")

    return genre_list, empty

# %% [markdown]
# 获得item-genre排列表和genre-item倒排表

# %%
def getItemgenre(movie_info_path, ave_score, K=50):
    """
    param:
        movie_info_path: 电影信息文件
        ave_score: item的全局平均得分字典 type dict, key:item, value: ratio
        K: genre_item排列表中记录前K个得分最高的item
    return:
        item_genre： item-genre排列表，记录每部电影的风格，以及风格的权重比， \
                     type dict, key: item, value:dict, key:genre, value:ratio
        genre_item： genre-item倒排表，记录每种风格中评分高的电影，\
                     type dict, key: genre, value:list [item1, item2, ...]
    """

    item_genre = {}
    genre_item = {}
    # 中间记录字典 key:genre, value: dict, key:item, value:ave_score
    record_tmp = {}
    # 读取电影信息
    movie_metadata = pd.read_csv(movie_info_path, usecols=[0, 6])

    for item, genres in movie_metadata.values:
        # 存储每部电影的风格
        print(item, genres)
        genre_list, f_void = getGenre(genres)
        if f_void:
            continue
        # 电影中每种风格的比重是=1/总的风格个数
        ratio = round(1.0 / len(genre_list), 3)

        if item not in item_genre:
            item_genre[item] = {}
        for genre in genre_list:
            item_genre[item][genre] = ratio

    # 遍历item-genre排列表，生成genre-item的中间表，记录每种风格下的电影item以及得分
    for item in item_genre:
        for genre in item_genre[item]:
            if genre not in record_tmp:
                record_tmp[genre] = {}
            # 赋值item的平均得分，如果在item_ave_score字典中没有该item，赋值为0
            record_tmp[genre][item] = ave_score.get(item, 0)

    # 遍历genre-item中间表，生成genre-item排列表，每种风格记录前K部评分最高电影
    for genre in record_tmp:
        if genre not in genre_item:
            genre_item[genre] = []
        for item, score in sorted(record_tmp[genre].iteritems(), key=operator.itemgetter(1), reverse=True)[:K]:
            genre_item[genre].append(item)
    return item_genre, genre_item

item_genre, genre_item = getItemgenre(movie_info_path, ave_score)
# Out:
# (1, 'Animation|Comedy|Family')
# (2, 'Adventure|Action|Thriller')
# (3, 'Crime|Comedy')
# (4, 'Comedy|Thriller|Crime')
# (5, 'Drama|Thriller')
# (7, 'Science Fiction|Thriller|Mystery')
# (8, 'Fantasy|Drama|Comedy|Family')
# (9, 'Drama')
# (10, 'Drama|War')
# (13, 'Comedy|Romance')
# (15, 'Music|Drama|Family')
# (17, 'Horror|Action|Thriller|Crime')
# (19, 'Drama|Comedy')
# (20, 'Drama|Romance')
# (21, 'Action|Comedy|Music|Family|Adventure')
# (22, 'Action|Drama|History|War')
# (23, 'Crime|Drama')
# (24, 'Crime|Action|Comedy|Thriller')
# (27, 'Action|Comedy|Crime|Thriller')
# (28, 'Drama')
# (29, 'Action|Crime|Fantasy')
# (31, 'Action|Thriller|Drama')
# (32, 'Documentary')
# (33, 'Thriller|Action|Crime')
# (36, 'Drama|Family|Romance')
# (37, 'Horror|Thriller')
# (39, 'Crime|Drama|Science Fiction|Thriller')
# (40, 'Comedy')
# (41, 'Comedy')
# (42, 'Comedy')
# (43, 'Drama|Thriller|Crime|Mystery|Romance')
# (45, 'Comedy|Drama|Romance')
# (46, 'Drama|Mystery')
# (47, 'Comedy|Drama|History')
# (48, 'Documentary')
# (49, 'Comedy|Drama|Romance')
# (50, 'Adventure|Action|Science Fiction')
# (51, 'Adventure|Drama|Romance|War')
# (53, 'Crime|Thriller|Drama')
# (54, 'Action|Drama|Science Fiction|Thriller')
# (56, 'Thriller|Crime')
# (57, 'Drama|Romance')
# (58, 'History|Drama')
# (59, 'Drama|Mystery|Romance')
# (60, 'Drama|Music|Mystery')
# (61, 'Comedy|Drama|Mystery')
# (62, 'Action|Adventure|Science Fiction')
# (65, 'Romance|Drama')
# (66, 'Comedy|Drama|Romance')
# (67, 'Comedy|Mystery')
# (69, 'Comedy|Drama|Romance')
# (70, 'Comedy|Drama|Romance')
# (73, 'Action|Adventure|Comedy|Drama|Western')
# (76, 'Action|Crime|Drama|Thriller')
# (78, 'Family|Adventure')
# (80, 'Action|Comedy|War')
# (82, 'Adventure|Science Fiction')
# (83, 'Drama|Comedy|Romance')
# (87, 'Drama')
# (88, 'Comedy|Drama|Romance')
# (89, 'Science Fiction|Drama|Thriller')
# (90, 'Comedy|Crime|Romance')
# (92, 'Action|Thriller|Crime|Romance')
# (93, 'Comedy|Drama')
# (94, 'Comedy|Family')
# (95, 'Animation|Family|Comedy|Adventure|Fantasy|Romance')
# (96, 'Action|Thriller|Science Fiction')
# (97, 'Adventure|Drama|Western')
# (99, 'Fantasy|Animation|Family')
# (100, 'Crime|Drama|Thriller')
# (101, 'Animation|Science Fiction')
# (103, 'Romance|Animation|Family|Adventure|Fantasy')
# (104, 'Fantasy|Science Fiction|Family')
# (105, 'Comedy|Family')
# (106, 'Drama|Horror|Mystery|Thriller')
# (107, 'Drama|Romance')
# (108, 'Comedy')
# (109, 'Comedy|Science Fiction')
# (110, 'Action|Adventure|Comedy|Family')
# (112, 'Adventure|Family')
# (116, 'Comedy|Drama|Romance')
# (118, 'Action|Adventure|Drama')
# (120, 'Drama|Thriller|Crime')
# (124, 'Drama|Mystery|Romance')
# (125, 'Drama|Fantasy|Romance|Science Fiction')
# (129, 'Crime|Drama|Romance|Thriller')
# (130, 'Thriller|Drama|Music|Crime')
# (131, 'Comedy|Drama|Romance')
# (133, 'Drama|Romance|War')
# (134, 'Mystery|Drama')
# (135, 'Science Fiction|Mystery|Adventure')
# (136, 'Comedy|Drama')
# (137, 'Drama')
# (138, 'Action|Comedy|Drama|Family')
# (140, 'Adventure|Comedy|Drama|Family')
# (141, 'Adventure|Drama|Science Fiction')
# (142, 'Adventure|Fantasy|Animation|Comedy|Family|Music')
# (144, 'Action|Thriller')
# (146, 'Drama|Romance')
# (149, 'Drama|Romance')
# (150, 'Comedy|Romance')
# (152, 'Comedy|Romance|Science Fiction')
# (155, 'Drama|Music|Romance')
# (156, 'Crime|Thriller')
# (157, 'Drama|War|Action')
# (158, 'Comedy')
# (159, 'Thriller|Mystery')
# (160, 'Crime|Drama|Mystery')
# (161, 'Action|Romance|War')
# (162, 'Drama')
# (165, 'Drama')
# (167, 'Comedy')
# (170, 'Drama|Romance')
# (171, 'Comedy|Science Fiction|Fantasy')
# (174, 'Adventure|Action')
# (175, 'Comedy|Science Fiction')
# (176, 'Horror|Action|Thriller|Science Fiction')
# (178, 'Drama')
# (180, 'Drama|War')
# (181, 'Adventure|Action|Science Fiction')
# (182, 'Drama|Crime')
# (183, 'Horror|Action|Thriller|Science Fiction')
# (185, 'Drama|Horror|Thriller')
# (188, 'Drama|War')
# (190, 'War|Drama|History|Action|Romance')
# (191, 'Drama|History|Music')
# (192, 'Drama')
# (196, 'Drama')
# (201, 'Horror|Comedy|Fantasy')
# (202, 'Romance|Fantasy|Drama|Comedy')
# (203, 'Western')
# (204, 'Adventure|Comedy|Science Fiction|Family')
# (205, 'Drama|History|War')
# (206, 'Science Fiction|Animation')
# (207, 'Drama|Comedy|History|Romance')
# (208, 'Comedy|Science Fiction')
# (209, 'Comedy|Music')
# (210, 'Adventure|Action')
# (211, 'Comedy|Drama|War')
# (215, 'Drama|Fantasy')
# (216, 'Comedy|Romance|Drama')
# (218, 'Crime|Thriller')
# (221, 'Drama|Romance')
# (222, 'Science Fiction|Action|Adventure|Thriller')
# (223, 'Drama')
# (224, 'Comedy|Drama|Romance')
# (225, 'Comedy|Family')
# (226, 'Action|Thriller')
# (227, 'Science Fiction|Action|Adventure|Thriller')
# (229, 'Science Fiction|Action|Adventure|Thriller')
# (230, 'Science Fiction|Adventure')
# (231, 'Action|Fantasy')
# (232, 'Crime|Action|Adventure|Drama|Western')
# (233, 'Action|Thriller')
# (234, 'Horror|Thriller|Adventure')
# (235, 'Comedy|Fantasy|Science Fiction')
# (236, 'Drama|Comedy')
# (237, 'Comedy|Drama|Romance')
# (238, 'Comedy|Crime')
# (239, 'Comedy|Crime|Drama')
# (242, 'Music|Drama|Comedy')
# (244, 'Action|Crime|Drama|Mystery|Thriller')
# (246, 'Comedy|Drama|Romance')
# (268, 'Comedy|Drama|Romance')
# (247, 'Action|Adventure|Family|Fantasy|Science Fiction|Thriller')
# (248, 'Action|Comedy|Thriller|Romance')
# (249, 'Science Fiction|Comedy|Crime')
# (251, 'Music|Comedy|Drama|Romance')
# (254, 'Action|Crime|Fantasy')
# (255, 'Comedy|Romance')
# (257, 'Action|Adventure|Comedy|Science Fiction')
# (258, 'Drama|Science Fiction|Mystery')
# (259, 'Adventure|Comedy|Family|Romance')
# (260, 'Horror|Science Fiction|Mystery')
# (261, 'Comedy|Family|Drama')
# (262, 'Comedy|Drama')
# (263, 'Science Fiction|Action|Adventure')
# (264, 'Fantasy|Horror|Thriller')
# (266, 'Adventure|Fantasy|Action|Science Fiction')
# (680, 'Adventure|Fantasy|Action|Science Fiction')
# (270, 'Thriller|Science Fiction|Mystery|Romance')
# (271, 'Adventure|Action|Thriller|Science Fiction')
# (272, 'Drama')
# (273, 'Action|Crime|Drama|Thriller')
# (274, 'Comedy|Romance')
# (275, 'Drama|Romance')
# (276, 'Drama|Romance')
# (277, 'Drama|Romance')
# (278, 'Drama|Romance')
# (283, 'Drama|Comedy|Romance')
# (284, 'Comedy|Drama|Romance')
# (285, 'Drama')
# (287, 'Drama')
# (288, 'Crime|Horror|Mystery')
# (289, 'History|Drama|Music')
# (290, 'Comedy|Romance')
# (291, 'Crime|Drama|Thriller')
# (292, 'Drama|History')
# (293, 'Crime|Drama|Thriller')
# (294, 'Comedy')
# (295, 'Drama|Action|Thriller')
# (297, 'Drama')
# (303, 'Drama')
# (298, 'Action|Crime|Science Fiction|Thriller')
# (299, 'Crime|Drama')
# (300, 'Action|Thriller')
# (301, 'Comedy|Romance')
# (302, 'Crime|Drama|Mystery|Thriller')
# (304, 'Action|Adventure|Drama|Family')
# (500, 'Action|Adventure|Drama|Family')
# (308, 'Fantasy|Drama|Mystery|Family')
# (309, 'Mystery|Crime|Drama|Thriller')
# (1606, 'Mystery|Crime|Drama|Thriller')
# (312, 'Crime|Drama|Mystery|Thriller')
# (313, 'Drama|Romance|Thriller')
# (315, 'Drama|Thriller')
# (317, 'Drama')
# (318, 'Drama|History|War')
# (319, 'Music|Comedy|Romance')
# (320, 'Documentary|Drama')
# (321, 'Comedy')
# (322, 'Action|Drama|Mystery|Thriller|Crime')
# (323, 'Action|Adventure|Thriller')
# (324, 'Drama|Thriller|Mystery')
# (325, 'Drama|Thriller|Romance')
# (326, 'Action|Drama')
# (327, 'Action|Crime|Drama')
# (328, 'Action|Drama|Mystery|Thriller')
# (329, 'Action|Drama|Thriller')
# (348, 'Action|Drama|Thriller')
# (332, 'Drama|Mystery|Thriller|Crime')
# (334, 'Thriller')
# (336, 'Drama|Action|Thriller|Crime')
# (338, 'Comedy')
# (339, 'Action|Drama|Thriller')
# (340, 'Drama')
# (341, 'Comedy|Drama')
# (343, 'Science Fiction|Horror|Action')
# (345, 'Comedy|Drama')
# (346, 'Comedy|Crime|Romance')
# (347, 'Comedy|Drama')
# (349, 'Thriller')
# (350, 'Thriller|Fantasy|Crime|Drama')
# (352, 'Adventure|Fantasy|Drama|Comedy|Music')
# (353, 'Adventure|Action|Horror|Science Fiction')
# (355, 'Science Fiction')
# (357, 'Drama')
# (358, 'Action|Adventure|Fantasy|Horror|Science Fiction|Thriller')
# (360, 'Documentary')
# (361, 'Crime|Thriller')
# (362, 'Music|Action|Comedy|Crime')
# (363, 'Action|Adventure|Thriller')
# (364, 'Crime|Comedy|Adventure')
# (365, 'Drama|Fantasy|Science Fiction|Thriller')
# (366, 'Drama|Crime')
# (367, 'Comedy|Drama|Romance')
# (368, 'Comedy')
# (369, 'Comedy')
# (370, 'Drama|Horror|Thriller|Romance')
# (372, 'Comedy|Drama|Romance')
# (373, 'Science Fiction')
# (374, 'Action|Adventure|Science Fiction|Family|Fantasy')
# (375, 'Drama')
# (378, 'Fantasy|Drama|Family')
# (380, 'Science Fiction|Action|Adventure|Thriller')
# (381, 'Drama|Comedy|Romance')
# (385, 'Action|Thriller')
# (386, 'Comedy|Family|Fantasy')
# (388, 'Action|Comedy|Crime')
# (389, 'Action|Adventure|Drama|Family')
# (391, 'Adventure|Fantasy|Action|Comedy|Family')
# (393, 'Comedy|Drama|Family')
# (394, 'Comedy|Crime|Drama|Music|Mystery|Romance')
# (395, 'Comedy')
# (396, 'Comedy|Crime|Horror|Thriller')
# (397, 'Crime|Action|Mystery|Thriller')
# (398, 'Adventure|Comedy|Family|Fantasy')
# (402, 'Fantasy|Drama|Thriller|Mystery|Romance')
# (403, 'Fantasy|Action')
# (404, 'Animation|Family')
# (405, 'Adventure|Action|Thriller')
# (406, 'Horror|Thriller')
# (407, 'Action|Comedy')
# (409, 'Comedy|Drama|Science Fiction')
# (410, 'Comedy')
# (414, 'Comedy|Drama')
# (416, 'Adventure|Drama|Western')
# (418, 'Family|Fantasy|Animation|Romance')
# (419, 'Comedy|Family|Fantasy')
# (420, 'Animation|Adventure|Family|Fantasy')
# (422, 'Adventure|Animation|Family')
# (423, 'Science Fiction|Adventure|Family|Fantasy')
# (425, 'Comedy|Drama')
# (427, 'Crime|Drama')
# (428, 'Comedy|Drama|Romance')
# (430, 'Comedy')
# (431, 'Adventure|Action|Fantasy')
# (432, 'Animation|Family|Music')
# (434, 'Adventure|Science Fiction|Action')
# (435, 'History|Drama|Western|Crime')
# (438, 'Horror|Thriller')
# (439, 'Horror')
# (440, 'Horror')
# (446, 'Horror')
# (447, 'Horror|Thriller')
# (449, 'Science Fiction|Adventure|Mystery')
# (450, 'Science Fiction|Action|Adventure|Thriller')
# (451, 'Romance')
# (452, 'Horror|Thriller')
# (453, 'Thriller|Horror')
# (454, 'Drama')
# (456, 'Action|Comedy')
# (457, 'Adventure')
# (458, 'History|Drama')
# (459, 'Drama')
# (461, 'Comedy|Drama')
# (464, 'Drama|Romance')
# (468, 'Drama')
# (469, 'Comedy|Drama')
# (470, 'Action|Adventure|Drama|History|Western')
# (471, 'Drama|Thriller|Mystery|War')
# (473, 'Adventure|Animation|Family')
# (475, 'Drama|Crime')
# (477, 'Comedy|Family|Fantasy')
# (479, 'Mystery|Romance|Thriller')
# (480, 'Mystery|Thriller')
# (482, 'Comedy|Romance')
# (483, 'Drama|Romance')
# (485, 'Drama|Family|Music|Romance')
# (486, 'Comedy|Drama|Romance')
# (487, 'Comedy|Romance')
# (489, 'Thriller|Drama|Romance')
# (490, 'Crime|Drama|Mystery|Romance|Thriller')
# (492, 'Drama')
# (494, 'Comedy|Drama')
# (496, 'Drama|Family|Fantasy')
# (497, 'Comedy|Romance')
# (499, 'Drama|Romance')
# (501, 'Animation|Family')
# (502, 'Comedy')
# (504, 'Crime|Drama')
# (505, 'Crime|Mystery|Thriller')
# (506, 'Drama')
# (511, 'Adventure|Drama|History|War')
# (512, 'Drama|Fantasy|Romance')
# (514, 'Comedy|Drama|Romance')
# (516, 'Comedy|Drama')
# (517, 'Comedy|Drama|Romance')
# (518, 'Drama|Thriller|Crime')
# (522, 'Crime|Drama|Comedy')
# (523, 'Crime|Drama')
# (526, 'Action|Adventure|Drama|History')
# (527, 'Drama|History')
# (531, 'Drama')
# (534, 'Drama|Crime')
# (535, 'Comedy|Romance')
# (536, 'Drama|Foreign')
# (537, 'Drama|Romance')
# (538, 'Animation|Family')
# (540, 'Action|Comedy|Crime')
# (541, 'Action|Fantasy')
# (542, 'Adventure|Animation|Drama|Family')
# (545, 'Comedy|Horror|Romance')
# (546, 'Action|Adventure|Drama|Thriller')
# (549, 'Adventure')
# (550, 'Action|Thriller')
# (551, 'Mystery|Horror|Thriller')
# (552, 'Science Fiction|Horror|Action')
# (554, 'Adventure|Action')
# (555, 'Drama')
# (556, 'Action|Western')
# (558, 'Drama|Fantasy')
# (559, 'Horror|Romance')
# (561, 'Drama|Horror|Science Fiction|Romance')
# (564, 'Crime|Horror|Thriller')
# (565, 'Thriller|Horror|Science Fiction')
# (566, 'Action|Drama|Thriller')
# (568, 'Action|Adventure|Crime')
# (569, 'Fantasy')
# (570, 'Drama|Action|Western')
# (571, 'Action|Comedy')
# (572, 'Drama|Action|Thriller')
# (573, 'Horror|Science Fiction|Thriller')
# (670, 'Horror|Science Fiction|Thriller')
# (574, 'Drama|Romance')
# (575, 'Action|Comedy|Drama|Western')
# (576, 'Action|Adventure|Thriller')
# (577, 'Comedy|Science Fiction|Family')
# (578, 'Crime|Action|Science Fiction')
# (579, 'Comedy')
# (581, 'Thriller|Crime')
# (583, 'Action|Crime|Drama|Thriller')
# (585, 'Comedy|Drama|Romance')
# (586, 'Action|Thriller')
# (588, 'Romance|Family|Animation|Fantasy|Music')
# (590, 'Horror|Thriller|Science Fiction')
# (591, 'Crime|Drama|Mystery|Thriller')
# (593, 'Drama|History|War')
# (594, 'Drama|Romance')
# (597, 'Action|Drama|Mystery|Thriller')
# (601, 'Drama|History|Romance|Thriller')
# (603, 'Drama|Mystery|Thriller')
# (604, 'Comedy|Romance')
# (605, 'Comedy|Music|Romance')
# (606, 'Drama')
# (607, 'Drama|Mystery')
# (608, 'Drama|Mystery|Thriller')
# (609, 'Comedy|Drama|Family|Romance')
# (610, 'Comedy|Music|Romance')
# (611, 'Drama|Mystery')
# (612, 'Adventure|Fantasy|Drama|Mystery')
# (613, 'Comedy|Romance')
# (614, 'Action|Drama|Western')
# (616, 'Horror')
# (618, 'Drama|Romance')
# (619, 'Drama|Thriller')
# (621, 'Action|Adventure|Family|Western')
# (622, 'Adventure|Family')
# (623, 'Fantasy|Drama|Comedy|Family')
# (627, 'Adventure')
# (628, 'Crime|Drama|Thriller')
# (629, 'Comedy|Music|Romance')
# (632, 'Drama|Romance')
# (636, 'Science Fiction|Action')
# (641, 'Drama|War')
# (647, 'Action|Drama|History')
# (649, 'Drama|Crime')
# (651, 'War')
# (653, 'Drama|Thriller|Crime')
# (654, 'Crime|Drama|Mystery|Thriller')
# (655, 'Crime|Drama')
# (656, 'Drama|Action|Thriller|Crime')
# (659, 'Comedy|Crime')
# (660, 'Drama|Comedy')
# (661, 'Western')
# (662, 'Science Fiction|Drama|Fantasy|Romance')
# (663, 'Comedy|Drama')
# (664, 'Drama')
# (667, 'Fantasy|Drama|Horror|Thriller')
# (669, 'Horror|Thriller')
# (671, 'Horror|Science Fiction')
# (672, 'Drama|Horror|Thriller')
# (673, 'Drama|Thriller')
# (674, 'Drama|Fantasy|Horror|Thriller')
# (677, 'Documentary')
# (678, 'Science Fiction|Action|Drama|Thriller')
# (681, 'Horror')
# (682, 'Horror|Thriller|Mystery')
# (684, 'Action|Drama|Thriller|Crime|Mystery')
# (685, 'Action|Adventure|Drama|Thriller')
# (687, 'Action|Comedy|Romance')
# (690, 'Adventure|Drama|History')
# (691, 'Mystery|Science Fiction')
# (693, 'Drama|Crime')
# (694, 'Drama|Romance')
# (695, 'Comedy|Drama|Romance')
# (696, 'Drama|Thriller')
# (699, 'Drama|Romance')
# (700, 'Comedy|Romance')
# (702, 'Comedy|Drama|Romance')
# (703, 'Comedy|Thriller|Mystery|Romance|Foreign')
# (705, 'Comedy|Music|Romance')
# (706, 'Horror')
# (707, 'Romance|Drama')
# (708, 'Drama')
# (709, 'Comedy|Drama|Romance')
# (710, 'Comedy')
# (712, 'Comedy|Drama')
# (713, 'Drama')
# (714, 'History|Drama|Romance')
# (715, 'Fantasy|Drama|Comedy|Thriller')
# (716, 'Comedy|Drama|Romance')
# (720, 'Action|Adventure|Drama|Romance')
# (721, 'Romance|Comedy')
# (722, 'Comedy')
# (723, 'Comedy|Drama')
# (724, 'Drama|Family|Romance')
# (725, 'Thriller|Comedy|Crime|Romance')
# (726, 'Drama|Family|Fantasy')
# (727, 'Drama|Music|Romance')
# (728, 'Comedy|Family|Romance')
# (729, 'Drama|Thriller')
# (731, 'Comedy|Drama|Family|Romance')
# (732, 'Comedy')
# (733, 'Drama|Romance')
# (734, 'Comedy')
# (735, 'Drama')
# (736, 'Drama|Romance')
# (738, 'Comedy|Drama|Family|Romance')
# (739, 'Romance|Comedy')
# (740, 'Drama|Romance')
# (742, 'Action|Thriller')
# (744, 'Drama|Thriller')
# (746, 'Comedy|Romance')
# (747, 'Comedy|Drama|Romance')
# (750, 'Drama|History|Mystery')
# (751, 'Adventure|Action|Thriller')
# (754, 'Crime|Drama|Thriller')
# (755, 'Adventure|Fantasy|Family')
# (756, 'Comedy')
# (757, 'Adventure|History|Drama|Family')
# (758, 'Action|Science Fiction')
# (759, 'Action|Thriller|Romance')
# (760, 'Horror|Science Fiction')
# (761, 'Crime|Drama|Thriller')
# (762, 'Comedy|Drama|Romance')
# (763, 'Comedy')
# (764, 'Comedy|Romance')
# (765, 'Comedy|Romance')
# (766, 'Comedy')
# (768, 'Fantasy|Comedy|Family')
# (769, 'Action|Adventure|Drama|Mystery|Science Fiction|Thriller')
# (770, 'Drama|Mystery|Thriller')
# (771, 'Adventure|Action|Drama|Science Fiction|Thriller')
# (772, 'Drama|Crime')
# (775, 'Comedy')
# (776, 'Drama|Fantasy')
# (777, 'Thriller|Drama|Horror|Mystery')
# (779, 'Action|Adventure|Thriller')
# (781, 'Comedy|Romance')
# (782, 'Action|Drama')
# (783, 'Comedy|Romance')
# (785, 'Comedy|Drama|Romance')
# (790, 'Comedy')
# (792, 'Action|Comedy|Thriller')
# (793, 'Comedy|Drama')
# (794, 'Comedy|Drama|Romance')
# (796, 'Comedy|Romance')
# (797, 'Thriller|Science Fiction|Action|Crime')
# (798, 'Action|Crime|Romance|Thriller')
# (802, 'Action|Adventure|Crime|Thriller')
# (803, 'History|War|Action|Drama')
# (804, 'Comedy')
# (805, 'Comedy|Mystery')
# (806, 'Drama|Action|Crime')
# (807, 'Drama|Romance')
# (809, 'Action|Drama|Thriller')
# (812, 'Drama|Family|Adventure')
# (815, 'Comedy|Romance')
# (816, 'Horror')
# (818, 'Comedy')
# (819, 'Action|Comedy')
# (820, 'Animation|Comedy|Drama|Family|Fantasy')
# (821, 'Comedy|Romance|Drama')
# (822, 'Drama')
# (823, 'Drama|Mystery|Thriller')
# (827, 'Action|Adventure|Thriller')
# (828, 'Adventure')
# (829, 'Action|Comedy|Thriller')
# (831, 'Action|Adventure|Science Fiction|Thriller')
# (832, 'Fantasy|Comedy|Family')
# (833, 'Action|Adventure|Comedy|Thriller')
# (834, 'Horror|Thriller')
# (836, 'Comedy|Romance')
# (837, 'Drama|Comedy|Romance')
# (840, 'Action|Crime|Drama|Thriller')
# (842, 'Adventure')
# (844, 'Comedy|Drama|Thriller')
# (845, 'Comedy|Drama')
# (846, 'Drama|Romance')
# (847, 'Documentary')
# (848, 'Crime|Drama|Mystery|Thriller')
# (849, 'Adventure')
# (853, 'Horror|Comedy')
# (854, 'Action|Comedy|Horror|Science Fiction')
# (855, 'Action|Drama|Music|Thriller')
# (856, 'Comedy|Drama')
# (858, 'Horror')
# (859, 'Horror|Mystery')
# (862, 'Family|Comedy')
# (864, 'Comedy|Drama')
# (866, 'Comedy|Drama|Fantasy')
# (869, 'Drama|Comedy|Romance')
# (870, 'Action|Comedy|Drama|Foreign|Romance')
# (871, 'Comedy')
# (872, 'Comedy|Drama|Romance')
# (873, 'Comedy|Romance')
# (874, 'Drama')
# (875, 'Drama|Romance|Thriller')
# (876, 'Action|Adventure|Comedy')
# (881, 'Action|Adventure|Comedy')
# (877, 'Action|Comedy|Romance')
# (880, 'Comedy|Drama')
# (882, 'Drama|Romance')
# (884, 'Documentary|Music')
# (885, 'Horror|Science Fiction|Thriller')
# (887, 'Drama')
# (888, 'Drama')
# (890, 'Action|Fantasy|Science Fiction')
# (891, 'Drama|History|Romance')
# (892, 'Comedy|Family|Science Fiction')
# (893, 'Comedy')
# (894, 'Comedy|Family')
# (895, 'Horror|Mystery')
# (900, 'Drama')
# (901, 'Comedy|Family')
# (903, 'Drama|Romance|Comedy')
# (905, 'Comedy|Drama|Romance')
# (908, 'Comedy|Crime')
# (909, 'Drama|Romance')
# (911, 'Drama|Crime|Mystery|Thriller')
# (913, 'Drama|Romance|Foreign')
# (914, 'Thriller')
# (915, 'Comedy|Drama')
# (916, 'Adventure|Family|Science Fiction')
# (917, 'Action|Crime|Drama|Thriller')
# (918, 'Drama|Fantasy|Romance')
# (920, 'Drama|Family')
# (921, 'Drama')
# (922, 'Drama|Fantasy|Western')
# (923, 'Drama')
# (924, 'Action|Drama')
# (925, 'Drama|Mystery|Science Fiction|Thriller')
# (926, 'Comedy')
# (929, 'Comedy|Drama|Family')
# (930, 'Action|Drama|Science Fiction|Thriller')
# (932, 'Comedy|Family')
# (935, 'War|Drama|History')
# (936, 'Comedy|Romance|Drama')
# (939, 'Crime|Drama')
# (940, 'Comedy|Crime|Music')
# (941, 'Comedy|Drama')
# (942, 'Drama|Music')
# (944, 'Comedy|War')
# (945, 'Comedy|Mystery|Romance|Thriller')
# (948, 'Comedy')
# (950, 'Drama')
# (952, 'Comedy')
# (953, 'Comedy|Drama|Family')
# (954, 'Documentary')
# (955, 'Drama|Romance')
# (956, 'Drama|Comedy')
# (957, 'Comedy|Drama')
# (959, 'Comedy|Drama')
# (960, 'Comedy|Drama')
# (962, 'Drama|Romance')
# (965, 'Music|Comedy|Romance')
# (967, 'Drama|Family')
# (969, 'Animation|Family|Music')
# (970, 'Comedy|Foreign')
# (971, 'Comedy|Romance|War')
# (972, 'Drama')
# (974, 'Drama|Thriller')
# (975, 'Drama|Thriller|Romance')
# (976, 'Action|Adventure|Science Fiction|Thriller')
# (978, 'Drama|Mystery|Thriller')
# (980, 'Drama|History')
# (981, 'Drama')
# (982, 'Action|Adventure|Thriller')
# (984, 'Action|Thriller')
# (986, 'Action|Thriller|Crime')
# (989, 'Animation|Comedy|Family|Music')
# (990, 'Drama|Romance')
# (991, 'Crime|Drama|Thriller')
# (992, 'Comedy|Thriller')
# (993, 'Animation|Family|Fantasy|Adventure|Comedy|Romance')
# (995, 'Comedy')
# (997, 'Comedy|Drama')
# (998, 'Comedy')
# (999, 'Comedy|Thriller|Mystery')
# (1000, 'Action|Comedy|Western')
# (1004, 'History|Action|Drama|Western')
# (1007, 'Music|Comedy')
# (1008, 'Drama')
# (1009, 'Drama|Romance')
# (1010, 'Drama|History')
# (1011, 'Comedy|Crime')
# (1012, 'Comedy|Drama')
# (1013, 'Adventure|Horror|Thriller')
# (1014, 'Comedy')
# (1016, 'Action|Thriller|Crime')
# (1017, 'Comedy|Drama')
# (1020, 'Drama|Mystery|Thriller|Crime')
# (1022, 'Documentary')
# (1023, 'Comedy|Family')
# (1024, 'Drama|Romance')
# (1025, 'Action|Adventure|Crime|Thriller')
# (1028, 'Romance|Comedy')
# (1029, 'Comedy|Drama')
# (1031, 'Action|Adventure|Drama|Family')
# (1032, 'Comedy|Family')
# (1033, 'Adventure|Comedy|Drama|Family')
# (1035, 'Comedy')
# (1036, 'Comedy|Fantasy|Family')
# (1037, 'Comedy|Drama|Family|Music|Romance')
# (1038, 'Action|Adventure|Mystery|Thriller')
# (1039, 'Drama')
# (1041, 'Comedy|Drama|Romance')
# (1042, 'Action|Drama|Mystery|Thriller')
# (1043, 'Comedy|Family|TV Movie')
# (1045, 'Drama')
# (1046, 'Drama|Crime')
# (1047, 'Comedy|Fantasy|Science Fiction')
# (1048, 'Comedy|Romance')
# (1049, 'Comedy|Family')
# (1052, 'Comedy|Horror')
# (1053, 'Comedy|Drama|Family')
# (1054, 'Comedy|Romance')
# (1059, 'Comedy')
# (1062, 'Action|Drama|Foreign|History|Thriller')
# (1064, 'Crime|Drama|Mystery|Thriller')
# (1066, 'Family|Animation|Adventure')
# (1067, 'Comedy|Crime|Drama')
# (1069, 'Crime|Comedy|Drama|Thriller')
# (1070, 'Drama|Comedy')
# (1071, 'Comedy')
# (1073, 'Crime|Thriller')
# (1074, 'Drama')
# (1077, 'Crime|Thriller')
# (1078, 'Animation|Comedy|Family')
# (1079, 'Fantasy|Comedy|Music')
# (1081, 'Comedy|Crime|Thriller')
# (1082, 'Drama|Romance')
# (1083, 'Crime|Drama|Thriller')
# (1084, 'Documentary|Drama|Foreign')
# (1085, 'Drama|Romance')
# (1088, 'Action|Science Fiction')
# (1089, 'Action|Adventure|Thriller')
# (1090, 'Drama|Thriller')
# (1091, 'Fantasy|Animation|Comedy|Family')
# (1092, 'Comedy')
# (1093, 'Comedy')
# (1095, 'Comedy')
# (1096, 'Comedy|Drama|Romance')
# (1099, 'Drama')
# (1100, 'Thriller|Comedy|Drama|Romance')
# (1101, 'Mystery|Drama|Comedy')
# (1102, 'Comedy|Romance')
# (1103, 'Drama|Comedy')
# (1105, 'Action|Adventure|Thriller')
# (1107, 'Drama|Thriller')
# (1108, 'Drama|Crime')
# (1109, 'Drama|Thriller|Mystery')
# (1110, 'Action|Comedy|Fantasy|Science Fiction')
# (1111, 'Comedy|Romance')
# (1112, 'Drama')
# (1113, 'Drama')
# (1114, 'Comedy|Crime|Drama')
# (1115, 'Drama|Comedy|Romance')
# (1117, 'Drama|Romance')
# (1118, 'Comedy')
# (1119, 'Drama|Romance')
# (1120, 'Comedy')
# (1122, 'Thriller|Crime|Drama|Mystery')
# (1128, 'Documentary')
# (1129, 'Drama|Comedy|Romance')
# (1131, 'Drama')
# (1132, 'Action|Comedy|Drama|Thriller')
# (1133, 'Adventure|Fantasy|Science Fiction|Family')
# (1134, 'Drama')
# (1136, 'History|Drama')
# (1137, 'Comedy|Drama|Romance')
# (1138, 'Comedy|Romance')
# (1139, 'Action|Crime|Thriller|Drama')
# (1142, 'Documentary')
# (1143, 'Drama|Thriller')
# (1145, 'Drama')
# (1146, 'Drama|Comedy')
# (1147, 'Comedy|Drama')
# (1148, 'Drama|Romance')
# (1149, 'Adventure|Drama')
# (1150, 'Drama|Thriller')
# (1151, 'Action|Drama|Crime|Thriller')
# (1152, 'Drama|Romance')
# (1154, 'Drama|Science Fiction|Mystery')
# (1156, 'Crime|Drama')
# (1159, 'Drama|Science Fiction|Thriller')
# (1160, 'Drama')
# (1162, 'Comedy')
# (1165, 'Comedy|Family')
# (1166, 'Comedy|Drama')
# (1168, 'Drama|History')
# (1169, 'Crime|Drama|Thriller')
# (1170, 'Comedy|Drama')
# (1171, 'Drama|Romance')
# (1173, 'Drama|Romance')
# (1174, 'Action|Drama|Thriller')
# (1175, 'Comedy|Romance')
# (1617, 'Comedy|Romance')
# (1177, 'Adventure|Comedy|Family')
# (1179, 'Action|Comedy|Family')
# (1180, 'Action|Comedy|Romance')
# (1185, 'Comedy')
# (1187, 'Action|Crime|Drama')
# (1188, 'Western|Adventure')
# (1189, 'Drama|Romance')
# (1190, 'Comedy|Drama|Romance')
# (1194, 'Drama')
# (1198, 'Crime|Drama|Thriller')
# (1200, 'Family|Adventure')
# (1203, 'Comedy|Music|Romance')
# (1204, 'Comedy|War')
# (1206, 'Action|Comedy')
# (1207, 'Action|Thriller|Mystery|Romance')
# (1208, 'Action|Crime|Drama|Thriller')
# (1209, 'Comedy|Drama|Romance')
# (1210, 'Action|Crime|Science Fiction|Thriller')
# (1211, 'Drama|Romance')
# (1212, 'Drama|Mystery|Romance')
# (1213, 'Drama|Thriller')
# (1215, 'Action|Science Fiction')
# (1216, 'Romance|Drama')
# (1217, 'Action|Adventure|Crime|Thriller')
# (1218, 'Comedy')
# (1220, 'Romance|Drama|Crime')
# (1221, 'Drama|Romance')
# (1222, 'Action|Thriller|Crime')
# (1223, 'Drama')
# (1225, 'Comedy|Drama|Family|Romance')
# (1228, 'Action|Thriller')
# (1231, 'Action|Thriller')
# (1232, 'Documentary|Music')
# (1234, 'Comedy')
# (1654, 'Comedy')
# (1237, 'Drama')
# (1238, 'Romance|Drama')
# (1239, 'Action|Adventure')
# (1244, 'Action|Adventure|Comedy|Crime|Thriller')
# (1245, 'Crime|Drama|Comedy')
# (1246, 'Adventure|Action|Comedy|Crime|Family')
# (1247, 'Action|Adventure|Comedy|Drama|Western')
# (1248, 'Mystery|Crime|Drama|Thriller')
# (1249, 'Comedy|Romance')
# (1250, 'Action')
# (1251, 'Drama|Comedy|Romance|Foreign')
# (1254, 'Comedy|Family')
# (1255, 'Romance|Drama')
# (1258, 'Comedy|Romance')
# (1260, 'Drama|Romance')
# (1262, 'Comedy|Drama|Romance')
# (1263, 'Action|Drama|Thriller')
# (1264, 'Action|Crime|Drama')
# (1265, 'Comedy|Drama')
# (1267, 'Mystery|Crime|Drama')
# (1268, 'Thriller|Drama|Romance')
# (1269, 'Comedy|Drama|Romance')
# (1271, 'Comedy|Drama|Family|Fantasy|Science Fiction')
# (1273, 'Drama|Mystery|Romance|Thriller')
# (1276, 'Drama')
# (1277, 'Drama|Action|Crime')
# (1278, 'Drama')
# (1279, 'Family')
# (1280, 'Action|Drama')
# (1281, 'Drama|Comedy')
# (1283, 'Comedy|Romance')
# (1284, 'Drama|Thriller')
# (1285, 'Comedy|Drama|History|Mystery')
# (1287, 'Comedy|Family')
# (1288, 'Comedy')
# (1290, 'Drama|Romance')
# (1291, 'Comedy')
# (1293, 'Action|Adventure|Family|Science Fiction')
# (1295, 'Comedy|Crime|Drama|Romance')
# (1297, 'Drama|Romance')
# (1299, 'Drama|Romance')
# (1301, 'Action|Comedy')
# (1302, 'unknown')
# (1308, 'unknown')
# (1311, 'Comedy|Drama|Romance')
# (1313, 'Mystery|Thriller|Drama|Romance|Crime')
# (1314, 'Action|Adventure|Thriller|Crime')
# (1315, 'Drama|Romance')
# (1318, 'Documentary')
# (1320, 'Thriller|Drama')
# (1321, 'Comedy')
# (1325, 'Romance|Comedy|Drama')
# (1326, 'Romance|Drama|Mystery')
# (1327, 'Drama|Thriller|Mystery|Romance')
# (1328, 'Drama')
# (1330, 'Drama|Romance|War')
# (1334, 'Comedy|Drama')
# (1335, 'Drama')
# (1336, 'Fantasy|Comedy|Science Fiction|Family')
# (1337, 'Family|Comedy')
# (1338, 'War|Drama')
# (1339, 'Comedy')
# (1341, 'War|Drama')
# (1343, 'Drama')
# (1348, 'Drama')
# (1350, 'unknown')
# (1351, 'Romance|Comedy')
# (1353, 'unknown')
# (1355, 'Drama|Romance')
# (1356, 'unknown')
# (1362, 'Action|Comedy')
# (1365, 'Drama')
# (1367, 'Animation|Drama|Fantasy')
# (1368, 'Drama|Comedy')
# (1374, 'Drama|Romance')
# (1376, 'Comedy')
# (1377, 'Comedy|Foreign|Romance')
# (1378, 'Documentary')
# (1379, 'Comedy|Romance')
# (1380, 'Drama')
# (1381, 'Drama|Romance')
# (1386, 'Science Fiction|Horror|Drama|Thriller')
# (1387, 'Drama|Romance')
# (1388, 'Drama|Mystery|Romance')
# (1391, 'Drama|Comedy|War')
# (1393, 'Thriller')
# (1396, 'Romance|Drama|Comedy')
# (1397, 'Drama')
# (1399, 'Thriller')
# (1400, 'Drama|History')
# (1401, 'Drama|Romance')
# (1406, 'Drama|Romance')
# (1408, 'Drama|Family|Fantasy')
# (1411, 'Science Fiction')
# (1413, 'Action|Adventure|Thriller')
# (1414, 'Action|Comedy')
# (1416, 'Action|Drama|Science Fiction|Thriller')
# (1422, 'Drama|Thriller')
# (1424, 'Comedy|Drama|Romance')
# (1425, 'Comedy|Drama')
# (1426, 'Drama|Comedy|Music')
# (1429, 'Comedy|Drama|Fantasy|Romance')
# (1680, 'Comedy|Drama|Fantasy|Romance')
# (1430, 'Drama')
# (1434, 'Crime|Comedy|Romance')
# (1436, 'Drama|Romance')
# (1437, 'Comedy')
# (1438, 'Drama')
# (1439, 'Crime|Drama|Romance')
# (1440, 'Crime|Drama')
# (1441, 'Comedy|Drama|Romance')
# (1443, 'Drama|Romance')
# (1444, 'Drama|Family|Comedy')
# (1445, 'Drama')
# (1447, 'Romance|Drama')
# (1448, 'Drama')
# (1449, 'Drama')
# (1450, 'Adventure|Romance')
# (1451, 'Mystery|Thriller|War')
# (1452, 'Comedy|Thriller|Mystery|Romance')
# (1453, 'Comedy|Fantasy|Romance')
# (1454, 'Romance|Western')
# (1457, 'Comedy|Romance')
# (1459, 'unknown')
# (1461, 'unknown')
# (1465, 'unknown')
# (1466, 'Drama')
# (1469, 'Action|Adventure|Drama|Family')
# (1470, 'Fantasy|Animation|Science Fiction|Family')
# (1471, 'Drama|Thriller')
# (1476, 'Crime')
# (1477, 'Action|Drama|Horror|Mystery|Thriller')
# (1625, 'Action|Drama|Horror|Mystery|Thriller')
# (1478, 'Action|Crime|Drama|History')
# (1479, 'Fantasy|Comedy|Drama')
# (1480, 'Romance|Comedy|Family|Fantasy')
# (1481, 'Comedy|Drama')
# (1486, 'Romance|Adventure|Crime|Drama')
# (1488, 'Drama|Romance')
# (1489, 'Comedy|Romance')
# (1491, 'Thriller|Action|Drama')
# (1495, 'Drama|Romance')
# (1496, 'Comedy|Family')
# (1500, 'Family|Comedy')
# (1503, 'Drama')
# (1507, 'Comedy|Crime')
# (1509, 'Family|Comedy|Crime')
# (1510, 'Drama|Action|Comedy|Crime')
# (1511, 'Comedy|Drama')
# (1513, 'Comedy|Romance')
# (1517, 'Action|Adventure|Comedy|Drama|Family')
# (1518, 'Drama')
# (1519, 'Crime|Drama')
# (1521, 'Comedy|Romance')
# (1522, 'Drama|Action|Thriller')
# (1524, 'Drama|Foreign')
# (1526, 'Crime|Drama|Romance|Thriller')
# (1527, 'Comedy|Romance')
# (1528, 'Science Fiction|Drama|Comedy')
# (1529, 'War|Drama|Comedy')
# (1530, 'Drama|Romance')
# (1532, 'Drama|Romance')
# (1534, 'Comedy|Drama')
# (1537, 'Comedy|Romance')
# (1538, 'Drama|Romance')
# (1543, 'Drama')
# (1544, 'Comedy|Family|Romance')
# (1545, 'Drama|Romance|War')
# (1549, 'Thriller')
# (1550, 'Crime|Comedy|Fantasy')
# (1554, 'Drama')
# (1556, 'Thriller|Action|Drama')
# (1558, 'Drama')
# (1561, 'Documentary|Foreign')
# (1564, 'unknown')
# (1567, 'Horror|Comedy|Drama|Fantasy')
# (1570, 'unknown')
# (1580, 'Drama|Romance')
# (1582, 'Thriller|Crime')
# (1585, 'Documentary')
# (1587, 'Action|Western')
# (1589, 'Comedy')
# (1594, 'Adventure|Documentary')
# (1595, 'Action|Adventure|Drama|Science Fiction|Thriller')
# (1597, 'Action|Drama|Thriller')
# (1598, 'Crime|Thriller|Drama')
# (1599, 'Drama')
# (1601, 'Comedy|Horror|Thriller')
# (1603, 'Comedy|Drama')
# (1604, 'Drama|Thriller')
# (1605, 'Comedy|Foreign|Romance')
# (1608, 'Adventure|Comedy|Family')
# (1610, 'Action|Crime|Drama|Romance|Thriller')
# (1611, 'unknown')
# (1613, 'Romance|Action|Drama|Thriller')
# (1615, 'Fantasy|Family|Action')
# (1618, 'Thriller|Crime')
# (1621, 'Crime|Drama|Romance|Thriller')
# (1624, 'Drama|Thriller')
# (1628, 'Drama|Foreign')
# (1629, 'Documentary')
# (1636, 'Comedy|Drama')
# (1637, 'Comedy|Drama')
# (1638, 'Crime|Drama')
# (1641, 'unknown')
# (1642, 'Drama|History')
# (1643, 'Drama')
# (1644, 'Comedy|Thriller')
# (1648, 'Drama|Romance')
# (1657, 'unknown')
# (1662, 'Comedy|Drama|Romance|Fantasy')
# (1664, 'Comedy|Crime')
# (1666, 'Drama')
# (1668, 'Comedy|Romance')
# (1669, 'Drama|Romance')
# (1670, 'Thriller|Comedy')
# (1672, 'Comedy|Drama')
# (1673, 'Action|Thriller')
# (1674, 'Drama')
# (1677, 'unknown')
# (1679, 'Romance|Crime|Drama')

# %% [markdown]
# 计算时间得分

# %%
def getTimeScore(timestamp):
    """
    param:
        timestamp: 时间戳
    return:
        时间权重得分
    """
    # 训练集中最近的日期，根据实际情况需要更改
    fix_time_stamp = 893286638
    total_sec = 24 * 60 * 60 * 100
    delta = (fix_time_stamp - timestamp) / total_sec
    # 返回时间得分，日期最近权重越大
    return round(1.0 / (1 + delta), 3)

# %% [markdown]
# 获得用户画像，即用户最喜爱的电影类型

# %%
def getUserProfile(data, item_genre, K=3):
    """
    param:
        data: type ndarray [[user, item, rating]]
        item_genre: item-genre排列表，记录每部电影的风格，以及风格的权重比， \
                    type dict, key: item, value:dict, key:genre, value:ratio
        K: 用户最喜爱的电影类型个数
    return:
        user_profile: 记录用户喜爱的风格和兴趣度，type:dict, key:user, value:list [genre, score]
    """
    # 得分阈值，大于等于阈值设置为喜欢
    score_thr = 4.0
    # user-genre中间表，key:user, value:dict, key:genre, value:score
    record_tmp = {}
    user_profile = {}
    for user, item, rate, ts in data:
        # 小于阈值的数据忽略
        if rate < score_thr:
            continue
        # 如果item不在item-genre排列表中，也跳过
        if item not in item_genre:
            continue

        if user not in record_tmp:
            record_tmp[user] = {}
        for genre in item_genre[item]:
            if genre not in record_tmp[user]:
                # 初始化用户对每种风格的电影兴趣度
                record_tmp[user][genre] = 0
            # 用户风格兴趣度=电影评分*电影中该类型的权重比*时间权重
            record_tmp[user][genre] += rate * item_genre[item][genre] * getTimeScore(int(ts))

    for user in record_tmp:
        if user not in user_profile:
            user_profile[user] = []
        total_score = 0
        for genre, score in sorted(record_tmp[user].iteritems(), key=operator.itemgetter(1), reverse=True)[:K]:
            user_profile[user].append((genre, score))
            total_score += score
        # 遍历用户喜欢的风格
        for index in range(len(user_profile[user])):
            # 将每种风格的得分归一化
            user_profile[user][index] = (user_profile[user][index][0], \
                                         round(user_profile[user][index][1] / total_score, 3))
    return user_profile

user_profile = getUserProfile(df_train.values, item_genre)

user_profile[7]
# Out:
# [('Drama', 0.583), ('Comedy', 0.229), ('Thriller', 0.188)]

# %% [markdown]
# 推荐系统

# %%
def recommendation(genre_item, user_profile, user, user_item, hot_rank, R=30):
    """
    param:
        genre_item: genre-item排列表，记录每种风格中评分高的电影，\
                   type dict, key: genre, value:list [item1, item2, ...]
        user_profile: 记录用户喜爱的风格和兴趣度，type:dict, key:user, value:list [genre, score]
        user: 用户id
        user_item: 用户-电影排列表 type:dict, key=user, value=dict, key=item, value=rate
        hot_rank: 热门电影列表, type:dict, key:user, value:dict, key:item, value:sim
        R: 推荐列表中电影个数
    return:
        recom_result: 推荐列表 type:dict, key:user, value:list [item1, item2, ...]
    """

    # 用户已观看的电影集合
    watched_item_list = user_item[user]

    recom_result = {}
    if user not in recom_result:
        recom_result[user] = []
    # 如果没有该用户的用户画像，推荐热门电影
    if user not in user_profile:
        recom_result[user] = hot_rank.keys()
    else:
        for genre, ratio in user_profile[user]:
            # 按照用户对电影风格的喜爱比重计算该风格推荐个数，向上取整
            num = int(R * ratio) + 1
            if genre not in genre_item:
                continue
            candidate = [item for item in genre_item[genre] if item not in watched_item_list]
            recom_list = candidate[:num]
            recom_result[user].extend(recom_list)
    return recom_result

# %% [markdown]
# ### 电影推荐

# %%
# 输入用户ID
user_id = input('Please input your user ID:')

recom_list = recommendation(genre_item, user_profile, user_id, user_item, hot_rank, reco_num)

# 输出推荐电影
print('\nRecommended movies：\n')

ranknum = 0
for idx in recom_list.values()[0]:
    ranknum += 1
    print("%d. %s" %(ranknum, movies[movies['movieId'] == idx]['title'].values[0]))
    print '-'*50
# Out:
# Please input your user ID:7
#
# Recommended movies：
#
# 1. They Made Me a Criminal
# --------------------------------------------------
# 2. Prefontaine
# --------------------------------------------------
# 3. Someone Else's America
# --------------------------------------------------
# 4. Pather Panchali
# --------------------------------------------------
# 5. Faust
# --------------------------------------------------
# 6. Some Mother's Son
# --------------------------------------------------
# 7. Santa with Muscles
# --------------------------------------------------
# 8. Shall We Dance?
# --------------------------------------------------
# 9. Stonewall
# --------------------------------------------------
# 10. They Made Me a Criminal
# --------------------------------------------------
# 11. North by Northwest
# --------------------------------------------------
